# %% [markdown]
# Задание 1

# %%
import requests

class Rate:
    def __init__(self, format='full', diff=False):
        self.format = format
        self.diff = diff  
    def exchange_rates(self):
        """
        Возвращает ответ сервиса с информацией о валютах в виде:
        
        {
            'AMD': {
                'CharCode': 'AMD',
                'ID': 'R01060',
                'Name': 'Армянских драмов',
                'Nominal': 100,
                'NumCode': '051',
                'Previous': 14.103,
                'Value': 14.0879
                },
            ...
        }
        """
        r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
        return r.json()['Valute']
     """Задание №1 возвращает название валюты (поле 'Name') с максимальным значением"""
    def max_value(self):
        response = self.exchange_rates()
        values = []
        for value in response.values():
            i = value ['Value'] / value ['Nominal']
            values.append(i)
        for key in response.values():
            j = key['Value'] / key['Nominal']
            if j == max(values):
                return print(f"Валюта: {key['Name']} с максимальным значением курса {key['Value']}")
            else:
                continue
    def make_format(self, currency):
        """
        Возвращает информацию о валюте currency в двух вариантах:
        - полная информация о валюте при self.format = 'full':
        Rate('full').make_format('EUR')
        {
            'CharCode': 'EUR',
            'ID': 'R01239',
            'Name': 'Евро',
            'Nominal': 1,
            'NumCode': '978',
            'Previous': 79.6765,
            'Value': 79.4966
        }
        
        Rate('value').make_format('EUR')
        79.4966
        """
        response = self.exchange_rates()
         
        if currency in response:
            if self.format == 'full':
                return response[currency]
            
#             if self.format == 'value':
#                 return response[currency]['Value']
         """Задание №2 Возвращает курс валюты на сегодня и разницу курса валют при условии равенства параметра diff == True"""   
            if  self.diff == True and self.format == 'value':
                x = response[currency]['Previous']- response[currency]['Value']
                a = response[currency]['Value']
                return print (f'Курс валюты на данный момент: {a} разница с предидущим курсом {x}')
            else:
                return response[currency]['Value']
                   
        return 'Error'
    
    def eur(self):
        """Возвращает курс евро на сегодня в формате self.format"""
        return self.make_format('EUR')
    
    def usd(self):
        """Возвращает курс доллара на сегодня в формате self.format"""
        return self.make_format('USD')

    def AZN(self):
        """Возвращает курс азербайджанского маната на сегодня в формате self.format"""
        return self.make_format('AZN')

# %%
a = Rate('full', True)

# %%
a.exchange_rates()
# Out:
# {'AUD': {'ID': 'R01010',
#   'NumCode': '036',
#   'CharCode': 'AUD',
#   'Nominal': 1,
#   'Name': 'Австралийский доллар',
#   'Value': 56.7401,
#   'Previous': 56.893},
#  'AZN': {'ID': 'R01020A',
#   'NumCode': '944',
#   'CharCode': 'AZN',
#   'Nominal': 1,
#   'Name': 'Азербайджанский манат',
#   'Value': 43.1754,
#   'Previous': 43.3928},
#  'GBP': {'ID': 'R01035',
#   'NumCode': '826',
#   'CharCode': 'GBP',
#   'Nominal': 1,
#   'Name': 'Фунт стерлингов Соединенного королевства',
#   'Value': 100.2836,
#   'Previous': 100.2282},
#  'AMD': {'ID': 'R01060',
#   'NumCode': '051',
#   'CharCode': 'AMD',
#   'Nominal': 100,
#   'Name': 'Армянских драмов',
#   'Value': 14.0486,
#   'Previous': 14.1183},
#  'BYN': {'ID': 'R01090B',
#   'NumCode': '933',
#   'CharCode': 'BYN',
#   'Nominal': 1,
#   'Name': 'Белорусский рубль',
#   'Value': 28.9084,
#   'Previous': 28.9274},
#  'BGN': {'ID': 'R01100',
#   'NumCode': '975',
#   'CharCode': 'BGN',
#   'Nominal': 1,
# ...

# %%
a.max_value()
# Out:
# Валюта: СДР (специальные права заимствования) с максимальным значением курса 105.6239

# %% [markdown]
# Задание №2

# %%
a = Rate('value', True)

# %%
a.make_format('AZN')
# Out:
# Курс валюты на данный момент: 43.1754 разница с предидущим курсом 0.21739999999999782

# %% [markdown]
# Задание 3

# %%
class Employee:
    def __init__(self, name, seniority, international_award):
        self.name = name
        self.seniority = seniority
        self.international_award = international_award
        self.grade = 1
    
    def grade_up(self):
        """Повышает уровень сотрудника"""
        self.grade += 1
    
    def publish_grade(self):
        """Публикация результатов аккредитации сотрудников"""
        print(self.name, self.grade)
    
    def check_if_it_is_time_for_upgrade(self):
        pass

# %%
class Designer(Employee):
    def __init__(self, name, seniority,international_award):
        super().__init__(name, seniority,international_award)
        # при условии наличия международной премии к изначальным баллам прибавляет 2 балла
        if international_award > 0:
            self.seniority = seniority + 2 
            
    def check_if_it_is_time_for_upgrade(self):
        # для каждой аккредитации увеличиваем счетчик на 1
        # пока считаем, что все разработчики проходят аккредитацию
        self.seniority += 1     
            
        # условие повышения сотрудника из презентации
        if self.seniority % 7 == 0:
            self.grade_up()        
        # публикация результатов
        return self.publish_grade()

# %%
alex = Designer('Александр', 0, 0)

# %%
for i in range(20):
    alex.check_if_it_is_time_for_upgrade()
# Out:
# Александр 1
# Александр 1
# Александр 1
# Александр 1
# Александр 1
# Александр 1
# Александр 2
# Александр 2
# Александр 2
# Александр 2
# Александр 2
# Александр 2
# Александр 2
# Александр 3
# Александр 3
# Александр 3
# Александр 3
# Александр 3
# Александр 3
# Александр 3

# %%
serg = Designer('Сергей', 2, 2)

# %%
for i in range(20):
    serg.check_if_it_is_time_for_upgrade()
# Out:
# Сергей 1
# Сергей 1
# Сергей 2
# Сергей 2
# Сергей 2
# Сергей 2
# Сергей 2
# Сергей 2
# Сергей 2
# Сергей 3
# Сергей 3
# Сергей 3
# Сергей 3
# Сергей 3
# Сергей 3
# Сергей 3
# Сергей 4
# Сергей 4
# Сергей 4
# Сергей 4
